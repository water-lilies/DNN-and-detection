# %%
import keras
import numpy as np
from keras.applications import vgg16, inception_v3, resnet50, mobilenet
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
from keras.applications.imagenet_utils import decode_predictions
import matplotlib.pyplot as plt
from keras import models
from keras import layers
from keras import optimizers
# %matplotlib inline


#https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt
# Out:
# Using TensorFlow backend.

# %%
#Load the VGG model
vgg_model = vgg16.VGG16(weights='imagenet')
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              


#Load the Inception_V3 model
inception_model = inception_v3.InceptionV3(weights='imagenet')


#Load the ResNet50 model
resnet_model = resnet50.ResNet50(weights='imagenet')
 
#Load the MobileNet model
mobilenet_model = mobilenet.MobileNet(weights='imagenet')
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.1/vgg16_weights_tf_dim_ordering_tf_kernels.h5
# 553467904/553467096 [==============================] - 252s 0us/step
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.5/inception_v3_weights_tf_dim_ordering_tf_kernels.h5
# 96116736/96112376 [==============================] - 51s 1us/step
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.2/resnet50_weights_tf_dim_ordering_tf_kernels.h5
# 102858752/102853048 [==============================] - 21s 0us/step
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.6/mobilenet_1_0_224_tf.h5
# 17227776/17225924 [==============================] - 7s 0us/step

# %%
vgg_model.summary()    # 138,357,544
#inception_model.summary() # 23,851,784
#resnet_model.summary()  # 25,636,712
#mobilenet_model.summary() # 4,253,864
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %%
filename = 'cat.jpg'
original = load_img(filename, target_size=(224, 224))
                               # 사이즈는 224*224로 항상 해야함!
plt.imshow(original)
plt.show()

numpy_image = img_to_array(original)
plt.imshow(np.uint8(numpy_image))
plt.show()

image_batch = np.expand_dims(numpy_image, axis=0)
print('image batch size', image_batch.shape)
plt.imshow(np.uint8(image_batch[0]))
# Out:
# image batch size (1, 224, 224, 3)

# %%
processed_image = vgg16.preprocess_input(image_batch.copy())
                          #전처리과정에서 변화가 생길 수 있으므로 copy() 사용
predictions = vgg_model.predict(processed_image)
print(predictions.shape)
print(predictions)
# Out:
# (1, 1000)
# [[4.05915898e-07 3.30235071e-06 2.00405722e-07 4.84790235e-07
#   7.51764787e-07 6.09398057e-06 2.99684359e-07 2.91176912e-06
#   5.37797587e-06 7.05132561e-06 2.51349411e-06 6.44150418e-07
#   6.20010860e-06 1.39507836e-06 8.77296884e-07 3.85474277e-06
#   9.12854011e-06 3.08063704e-06 1.48078789e-06 2.14849297e-06
#   7.54337975e-07 1.29393029e-05 2.02379624e-06 3.73676153e-06
#   3.34149918e-05 3.42941604e-07 4.09469550e-07 6.12346241e-07
#   6.52832114e-07 8.74050784e-07 6.67915288e-07 8.95577386e-07
#   2.29811781e-06 3.28840798e-07 2.91270396e-07 1.47804315e-07
#   1.90844548e-06 5.70716622e-07 6.88963155e-06 2.75578782e-06
#   4.90474861e-07 2.03239551e-06 5.23350025e-07 1.00757791e-06
#   3.41134046e-06 3.42525027e-06 1.67121334e-06 1.96714905e-06
#   1.25268571e-07 6.82399502e-07 4.62105959e-07 5.70807024e-05
#   1.31117247e-06 3.28559781e-06 1.12664770e-06 3.77763854e-07
#   1.23001644e-06 2.12196142e-07 3.75182452e-07 1.45000058e-06
#   9.87852104e-07 3.08702965e-07 4.68735351e-07 1.16898480e-06
#   1.63965831e-06 3.39207162e-07 5.15767715e-05 1.36495839e-06
#   1.09691246e-05 2.62719982e-06 3.32134050e-07 1.84227144e-06
#   8.45364241e-07 6.85980012e-06 5.24384632e-07 2.81467646e-06
#   2.80944710e-06 1.34133438e-06 4.16421199e-06 2.84406860e-06
#   5.45045350e-06 8.62616503e-07 2.39099008e-05 1.77327966e-05
#   5.61936531e-07 5.74131491e-06 1.46996608e-05 4.67399059e-06
#   3.03679508e-06 2.45479396e-06 2.49491904e-06 3.08951229e-07
#   4.16845114e-06 1.57594113e-05 7.22765326e-05 2.06543314e-06
#   6.80957919e-06 1.81767573e-05 3.57566241e-05 4.23582742e-06
#   7.37800929e-06 7.42720795e-06 5.36970447e-06 4.08990854e-06
#   3.92293623e-06 3.93121309e-06 6.67722925e-05 8.42974259e-06
#   1.88306585e-04 1.04278399e-04 8.21612502e-07 4.26592396e-06
#   3.74414640e-07 8.86468968e-07 7.83536325e-06 9.81293510e-07
#   5.43376473e-07 1.10615827e-06 3.79927906e-06 4.64545053e-07
#   2.05475317e-06 2.79063465e-06 5.25398320e-07 9.19815875e-07
#   8.13753672e-07 6.12650229e-06 4.16515178e-07 1.04474006e-04
#   4.35965967e-06 3.90878313e-06 3.90513878e-06 1.06084201e-06
#   1.44052206e-06 1.04693220e-06 3.45086221e-07 7.55405665e-07
#   2.27363239e-06 1.33270487e-06 2.45265601e-05 2.95143182e-05]]

# %%
label_vgg = decode_predictions(predictions, top=10)
          # 확률값에서 max값을 가져옴. top=10이므로 10개까지!
print(label_vgg)
# Out:
# [[('n02123045', 'tabby', 0.32754445), ('n02124075', 'Egyptian_cat', 0.23719856), ('n02127052', 'lynx', 0.13906546), ('n02123159', 'tiger_cat', 0.13013493), ('n02123394', 'Persian_cat', 0.09777182), ('n03223299', 'doormat', 0.008973129), ('n04152593', 'screen', 0.0032300986), ('n02130308', 'cheetah', 0.002677828), ('n02123597', 'Siamese_cat', 0.0026385672), ('n03793489', 'mouse', 0.002637014)]]

# %%
processed_image = resnet50.preprocess_input(image_batch.copy())
predictions = resnet_model.predict(processed_image)
label_resnet = decode_predictions(predictions, top=3)
label_resnet
# Out:
# [[('n02123045', 'tabby', 0.7849028),
#   ('n02124075', 'Egyptian_cat', 0.115786955),
#   ('n02123394', 'Persian_cat', 0.031741302)]]

# %%
processed_image = mobilenet.preprocess_input(image_batch.copy())
predictions = mobilenet_model.predict(processed_image)
label_mobilenet = decode_predictions(predictions)
label_mobilenet
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-aaa054395da1> in <module>
#       1 processed_image = mobilenet.preprocess_input(image_batch.copy())
# ----> 2 predictions = mobilenet_model.predict(processed_image)
#       3 label_mobilenet = decode_predictions(predictions)
#       4 label_mobilenet
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1439
#    1440         # Case 2: Symbolic tensors or Numpy array-like.
# -> 1441         x, _, _ = self._standardize_user_data(x)
#    1442         if self.stateful:
#    1443             if x[0].shape[0] > batch_size and x[0].shape[0] % batch_size != 0:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#     577             feed_input_shapes,
#     578             check_batch_axis=False,  # Don't enforce the batch size.
# --> 579             exception_prefix='input')
#     580
#     581         if y is not None:
#
# ~\Anaconda3\lib\site-packages\keras\engine\training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     143                             ': expected ' + names[i] + ' to have shape ' +
#     144                             str(shape) + ' but got array with shape ' +
# --> 145                             str(data_shape))
#     146     return data
#     147
#
# ValueError: Error when checking input: expected input_4 to have shape (224, 224, 3) but got array with shape (299, 299, 3)

# %%
filename = 'cat.jpg'
original = load_img(filename, target_size=(299, 299))
                            #inception사용을 위해 크기를 바꾸줌
numpy_image = img_to_array(original)
image_batch = np.expand_dims(numpy_image, axis=0)

processed_image = inception_v3.preprocess_input(image_batch.copy())
predictions = inception_model.predict(processed_image)
label_inception = decode_predictions(predictions)
label_inception
# Out:
# [[('n02123045', 'tabby', 0.77805036),
#   ('n02124075', 'Egyptian_cat', 0.09324035),
#   ('n02123159', 'tiger_cat', 0.07594551),
#   ('n02123394', 'Persian_cat', 0.004828972),
#   ('n02138441', 'meerkat', 0.0024570054)]]

# %%
import cv2
img = cv2.imread("cat.jpg")
img = cv2.resize(img, (1000,1000))
    # 이미지위에 글자를 쓰기위해서 키웠음
cv2.putText(img, "VGG16: {}, {:.2f}".format(label_vgg[0][0][1], label_vgg[0][0][2]) , (350, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
                                            #이름, 확률값
cv2.putText(img, "MobileNet: {}, {:.2f}".format(label_mobilenet[0][0][1], label_mobilenet[0][0][2]) , (350, 75), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
cv2.putText(img, "Inception: {}, {:.2f}".format(label_inception[0][0][1], label_inception[0][0][2]) , (350, 110), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
cv2.putText(img, "ResNet50: {}, {:.2f}".format(label_resnet[0][0][1], label_resnet[0][0][2]) , (350, 145), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
cv2.imwrite("out.jpg", img)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-35f901eb77eb> in <module>
#       5 cv2.putText(img, "VGG16: {}, {:.2f}".format(label_vgg[0][0][1], label_vgg[0][0][2]) , (350, 40), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
#       6                                             #이름, 확률값
# ----> 7 cv2.putText(img, "MobileNet: {}, {:.2f}".format(label_mobilenet[0][0][1], label_mobilenet[0][0][2]) , (350, 75), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
#       8 cv2.putText(img, "Inception: {}, {:.2f}".format(label_inception[0][0][1], label_inception[0][0][2]) , (350, 110), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
#       9 cv2.putText(img, "ResNet50: {}, {:.2f}".format(label_resnet[0][0][1], label_resnet[0][0][2]) , (350, 145), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 0, 0), 3)
#
# NameError: name 'label_mobilenet' is not defined

# %%
from keras.preprocessing.image import ImageDataGenerator

test_generator = ImageDataGenerator()
test_generator = test_datagen.flow_from_directory('cnntest',target_size=(224,224), batch_size=3,
                                               class_mode='binary', shuffle=False)
X,T = test_generator.next()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-1c092675d9a8> in <module>
#       2
#       3 test_generator=ImageDataGenerator()
# ----> 4 test_generator= test_datagen.flow_from_directory('cnntest',target_size=(224,224),batch_size=3,
#       5                                                class_mode='binary',shuffle=False)
#       6 X,T=test_generator.next()
#
# NameError: name 'test_datagen' is not defined

# %%
decode_vgg = decode_predictions(
    vgg_model.predict(vgg16.preprocess_input(X.copy())), top=3)

decode_resenet = decode_predictions( 
    resnet_model.predict(resnet50.preprocess_input(X.copy())),top=3)

decode_mobilenet = decode_predictions( 
    mobilenet_model.predict(mobilenet.preprocess_input(X.copy())),top=3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3fd9a724c919> in <module>
#       1 decode_vgg = decode_predictions(
# ----> 2     vgg_model.predict(vgg16.preprocess_input(X.copy())), top=3)
#       3
#       4 decode_resenet = decode_predictions(
#       5     resnet_model.predict(resnet50.preprocess_input(X.copy())),top=3)
#
# NameError: name 'X' is not defined

# %%
for i in range(X.shape[0]):
    img=cv2.resize(X[i]*255,(1000,1000))
    img=cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
    cv2.putText(img, "VGG16:{decode_vgg[i][0][i]}", (50,50), 
                cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),3)
    cv2.putText(img, "resnet:{decode_resnet[i][0][i]}", (50,50), 
                cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),3)
    cv2.putText(img, "mobilenet:{decode_mobilenet[i][0][i]}", (50,50), 
                cv2.FONT_HERSHEY_SIMPLEX,1,(255,0,0),3)
    cv2.imwrite("out.jpg",img)
